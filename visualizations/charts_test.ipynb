# %%
from simulator import StartupSimulator
import altair as alt

# adjust the path if your CSV is in a subfolder like 'data/...'
sim = StartupSimulator("saas_financial_market_dataset.csv")

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
from altair_charts import build_line_chart, build_scatter_plot

# %%
line_chart = build_line_chart(sim)
line_chart
# Out:
# alt.FacetChart(...)

# %%
scatter_chart = build_scatter_plot(sim)
scatter_chart
# Out:
# alt.Chart(...)

# %%
line_chart.save("line_chart.html")
scatter_chart.save("scatter_plot.html")
